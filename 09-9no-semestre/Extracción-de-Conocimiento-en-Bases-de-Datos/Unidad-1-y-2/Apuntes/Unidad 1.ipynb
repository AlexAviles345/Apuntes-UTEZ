# %%
# pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('AB_NYC_2019.csv') # leer un archivo csv

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info() # Detalles del dataframe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [raw]
# Describe sirve para ...

# %%
df.describe() # Devuelve las variables basicas y estadisticas
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.shape # Devuelve numero de registros y columnas
# Out:
# (48895, 16)

# %% [raw]
# Si es uno solo, solo van corchetes, pero si son mas, entonces van dos corchetes para indicar la lista

# %%
df[['name', 'price']]
# Out:
#                                                     name  price
# 0                     Clean & quiet apt home by the park    149
# 1                                  Skylit Midtown Castle    225
# 2                    THE VILLAGE OF HARLEM....NEW YORK !    150
# 3                        Cozy Entire Floor of Brownstone     89
# 4       Entire Apt: Spacious Studio/Loft by central park     80
# ...                                                  ...    ...
# 48890    Charming one bedroom - newly renovated rowhouse     70
# 48891      Affordable room in Bushwick/East Williamsburg     40
# 48892            Sunny Studio at Historical Neighborhood    115
# 48893               43rd St. Time Square-cozy single bed     55
# 48894  Trendy duplex in the very heart of Hell's Kitchen     90
#
# [48895 rows x 2 columns]

# %%
df[df['price']>300] # Condicion para la columna price
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 116       26969                2 story family home in Williamsburg     115307
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %% [raw]
# Instalar librería para leer archivos excel viejos

# %%
# !pip install xlrd openpyxl
# Out:
# ...
#
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    ---------------------------------------- 3/3 [openpyxl]
#
# ...

# %%
df_investigadores = pd.read_excel('investigadores.xls')

# %%
df_investigadores
# Out:
#    Temperatura(°C)  Eficiencia (%)
# 0               20              30
# 1               25              34
# 2               30              39
# 3               35              42
# 4               40              46
# 5               45              49
# 6               50              51

# %%
df_ventas = pd.read_excel('ventas_electronicas.xlsx')

# %%
df_ventas  # Muestra solo de la primera pagina
# Out:
#       Producto    Marca          Modelo   Precio  Cantidad Fecha_Venta  \
# 0    OnePlus 9  OnePlus   OnePlus 9 875  1932.75         4  2024-12-09
# 1      Pixel 6   Lenovo     Pixel 6 113  1253.10         7  2025-03-20
# 2    iPhone 13  Samsung   iPhone 13 373  1101.68         2  2025-03-12
# 3    OnePlus 9     Asus   OnePlus 9 743  1249.52         1  2024-07-10
# 4   Galaxy S21     Dell  Galaxy S21 501   620.14         1  2025-03-10
# 5      Pixel 6    Apple     Pixel 6 781   576.47         5  2024-10-05
# 6   Galaxy S21   Xiaomi  Galaxy S21 513   851.78         3  2025-01-06
# 7      Pixel 6   Google     Pixel 6 825   455.12        10  2025-03-25
# 8      Pixel 6     Sony     Pixel 6 916  1109.73         8  2024-12-14
# 9    iPhone 13     Sony   iPhone 13 417    56.42         8  2025-06-15
# 10     Pixel 6   Google     Pixel 6 641  1394.96        10  2025-02-07
# 11     Pixel 6   Xiaomi     Pixel 6 908  1227.69         3  2025-06-14
# ...

# %%
df_laptos = pd.read_excel('ventas_electronicas.xlsx', sheet_name='Laptops') # Se trae la pagina de nombre datos

# %%
df_laptos
# Out:
#            Producto    Marca               Modelo   Precio  Cantidad  \
# 0          Dell XPS     Dell         Dell XPS 252  1496.85         3
# 1          Dell XPS   Google         Dell XPS 404   293.58        10
# 2        HP Spectre       HP       HP Spectre 553    90.28         4
# 3   Lenovo ThinkPad    Apple  Lenovo ThinkPad 116  1373.63         8
# 4   Lenovo ThinkPad   Xiaomi  Lenovo ThinkPad 182  1815.88         8
# 5   Lenovo ThinkPad   Lenovo  Lenovo ThinkPad 763   438.14         8
# 6   Lenovo ThinkPad   Lenovo  Lenovo ThinkPad 794  1902.15         4
# 7        HP Spectre   Xiaomi       HP Spectre 270  1267.88         3
# 8       MacBook Air     Dell      MacBook Air 452  1365.76         6
# 9   Lenovo ThinkPad     Dell  Lenovo ThinkPad 610   390.10         1
# 10     Asus ZenBook   Lenovo     Asus ZenBook 964   952.32         8
# 11       HP Spectre       HP       HP Spectre 357  1858.03         5
# 12         Dell XPS  OnePlus         Dell XPS 472  1435.84        10
# ...

# %% [raw]
# Con esto ahora ventas es una coleccion de dataframe, osea un diccionario

# %%
df_ventas = pd.read_excel('ventas_electronicas.xlsx', sheet_name=None) # Se trae todas las paginas

# %%
df_ventas['Tablets']  # Se trae la pagina en concreto de Tablets
# Out:
#        Producto    Marca           Modelo   Precio  Cantidad Fecha_Venta  \
# 0      iPad Pro     Asus     iPad Pro 249  1462.12         2  2024-10-12
# 1    Lenovo Tab   Lenovo   Lenovo Tab 362  1941.88         9  2024-10-29
# 2    Lenovo Tab   Xiaomi   Lenovo Tab 173  1148.47         2  2024-10-01
# 3    Lenovo Tab   Lenovo   Lenovo Tab 609    85.10         4  2025-04-01
# 4   Amazon Fire   Xiaomi  Amazon Fire 318  1853.81         3  2025-02-09
# 5    Galaxy Tab    Apple   Galaxy Tab 788   773.15         5  2024-09-04
# 6    Surface Go     Dell   Surface Go 508  1579.73         4  2025-01-05
# 7    Lenovo Tab  OnePlus   Lenovo Tab 773   447.57         6  2025-03-04
# 8    Surface Go   Xiaomi   Surface Go 758  1261.04         1  2024-11-26
# 9    Surface Go    Apple   Surface Go 764   306.04         4  2025-03-15
# 10     iPad Pro     Dell     iPad Pro 565   773.47         2  2024-10-23
# 11  Amazon Fire     Dell  Amazon Fire 704   188.79         4  2024-08-14
# ...

# %% [raw]
# NOTA: SI PUEDE LEER FORMULAS

# %% [raw]
# Pedir solo ciertas columnas a una pagina

# %%
df_accesorios = pd.read_excel('ventas_electronicas.xlsx', sheet_name='Accesorios', usecols='A:D, G')

# %%
df_accesorios
# Out:
#       Producto    Marca          Modelo   Precio Vendedor
# 0   Power Bank     Dell  Power Bank 438   195.06    María
# 1     Cargador  Samsung    Cargador 607  1113.03      Ana
# 2     Cargador   Lenovo    Cargador 654   790.11   Carlos
# 3        Funda       HP       Funda 199   944.47    Laura
# 4     Cargador     Asus    Cargador 986  1426.40     Juan
# 5        Funda   Lenovo       Funda 405   322.49     Luis
# 6    Audífonos    Apple   Audífonos 380   597.61     Luis
# 7    Audífonos     Dell   Audífonos 314   185.42    María
# 8        Funda   Lenovo       Funda 758  1238.68   Carlos
# 9    Audífonos  OnePlus   Audífonos 925  1708.63     Luis
# 10   Audífonos     Dell   Audífonos 187   495.59    Elena
# 11       Funda   Google       Funda 270  1430.31     Juan
# 12  Power Bank   Lenovo  Power Bank 976   598.54     Juan
# 13   Cable USB   Google   Cable USB 561   429.22      Ana
# 14   Audífonos     Sony   Audífonos 269   311.14     Juan
# ...

# %% [raw]
# Si se salta 5 columnas, va a tomar el primer registro que encuentre como encabezado

# %%
df_accesorios = pd.read_excel('ventas_electronicas.xlsx', sheet_name='Accesorios', skiprows=5)

# %%
df_accesorios
# Out:
#       Cargador     Asus    Cargador 986   1426.4   6 2024-09-07 00:00:00  \
# 0        Funda   Lenovo       Funda 405   322.49   1          2025-03-29
# 1    Audífonos    Apple   Audífonos 380   597.61   8          2025-01-26
# 2    Audífonos     Dell   Audífonos 314   185.42   8          2025-02-01
# 3        Funda   Lenovo       Funda 758  1238.68   1          2025-04-21
# 4    Audífonos  OnePlus   Audífonos 925  1708.63   9          2025-03-02
# 5    Audífonos     Dell   Audífonos 187   495.59   1          2025-06-01
# 6        Funda   Google       Funda 270  1430.31   6          2025-01-27
# 7   Power Bank   Lenovo  Power Bank 976   598.54  10          2025-01-16
# 8    Cable USB   Google   Cable USB 561   429.22  10          2024-07-25
# 9    Audífonos     Sony   Audífonos 269   311.14   5          2025-04-22
# 10  Power Bank   Google  Power Bank 269   960.35   6          2024-08-27
# 11  Power Bank  Samsung  Power Bank 180   851.99   8          2024-10-13
# ...
